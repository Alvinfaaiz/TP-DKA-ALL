# %% [markdown]
# <div align="center">
# <h1>Tugas Pendahuluan Praktikum Dasar Kecerdasan Artifisial</h1>
# <h3>Modul 2: Pengenalan Python</h3>
# </div>

# %% [markdown]
# ### 1. Program Sederhana: Cetak Teks & Operasi Aritmatika

# %% [markdown]
# Buat program yang mencetak teks "**Halo, Dunia!**" dan melakukan operasi penjumlahan dua angka.

# %%
print(None)

a = 10
b = 5
hasil = None
print(None)

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output** |
# |-----------|-----------|
# |           | `Hello, World!` <br> `Hasil penjumlahan: 15`|

# %% [markdown]
# ### 2. Pengkondisian (if-elif-else)

# %% [markdown]
# Buat program yang meminta pengguna memasukkan angka dan menentukan apakah angka tersebut **positif**, **negatif**, atau **nol**.

# %%
angka = int(input(None)

if None:
    print("Angka positif")
elif None:
    print("Angka negatif")
else:
    print("Angka nol")

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output** |
# |-----------|-----------|
# | `10` | `Angka positif` |
# | `-5` | `Angka negatif` |
# | `0`  | `Angka nol` |

# %% [markdown]
# ### 3. Perulangan (for & while)

# %% [markdown]
# a. Gunakan `for loop` untuk mencetak angka **1 hingga 5**.

# %%
for i in range(None):
    print(None)

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output**               |
# |-----------|--------------------------|
# |           | `1`<br>`2`<br>`3`<br>`4`<br>`5`<br>`6` |

# %% [markdown]
# b. Gunakan `while loop` untuk mencetak angka **1 hingga 3**.

# %%
x = 1
while None:
    print(None)
    x += None

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output**               |
# |-----------|--------------------------|
# |           | `1`<br>`2`<br>`3`|

# %% [markdown]
# ### 4. List dan Dictionary

# %% [markdown]
# Buat list berisi 5 nama makanan dan **dictionary** berisi daftar harga makanan tersebut. Cetak harga dari salah satu makanan.

# %%
makanan = ["Nasi Goreng", "Mie Ayam", "Soto", "Bakso", "Gado-Gado"]

harga_makanan = {"Nasi Goreng": 15000, "Mie Ayam": 12000, "Soto": 13000, "Bakso": 14000, "Gado-Gado": 10000}

# %%
print("List Makanan:", None)
print("Harga Bakso:", None)

# %%
print("List Makanan:", None)
print("Harga Mie Ayam:", None)

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output**               |
# |-----------|--------------------------|
# |           | List Makanan: [Nasi Goreng, Mie Ayam, Soto, Bakso, Gado-Gado]<br>Harga Bakso: 14000 |
# |           | List Makanan: [Nasi Goreng, Mie Ayam, Soto, Bakso, Gado-Gado]<br>Harga Mie Ayam: 12000 |

# %% [markdown]
# ### 5. Fungsi: Menghitung Diskon Harga

# %% [markdown]
# Buat fungsi yang menerima **harga barang** dan **persentase diskon**, lalu mengembalikan harga setelah diskon.

# %%
def hitung_diskon(None, None):
    return harga - (harga * diskon / 100)

diskon = int(input())
harga_barang = int(input())

harga_setelah_diskon = None
print(None)

# %% [markdown]
# *Test case* program
#
# | **Input** | **Output**               |
# |-----------|--------------------------|
# | 100000 <br> 20 | 80000 |
# | 50000 <br> 10 | 45000 |
